# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера</b>
#
#
# Привет, Павел! Давай знакомиться! Меня зовут Дмитрий Махортов, и я буду проверять твой проект. Сразу предлагаю общение на «ты» 🙂, но если тебе это не комфортно, то дай знать, и мы перейдем на «вы».
#
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе погрузиться в увлекательный мир работы с данными и вырасти в крепкого профи. Это отдаленная цель. А ближайшая - сделать твою работу еще лучше )).
#
#
# Все ключевые этапы в работе выполнены, и я вижу что с проектом ты справшяешься. Есть моменты, которые нужно доработать, но я уверен, у тебя все получится.
#
# Расскажу как обычно проходит проверка:
# Бывают моменты, которые требуют пристального внимания. Комментарии по ним выделены <span style='background-color:#F7B3A4'> красным цветом </span> и обозначены значком 🛑. После их доработки проект будет принят.  🙂
#
# <span style='background-color:#B7EBA7'> Зеленым цветом </span> и значком ✅ отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах. Или советы «со звездочкой», которые помогут тебе в будущем.
#
# <span style='background-color:#F9EDA6'>Жёлтым цветом </span> и значком ⚠️ выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# 	<font size="3"><b>образец комментария студента</b></font>
#
# Можешь использовать этот комментарий. Просто удали этот текст и вместо него напиши свой 🙂
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# 	<font size="3"><b>Приветствие!</b></font>
#
# Надеюсь приятно поработать! 🙂
#
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера v2</b>
#
# Привет!
#
# Начинаю вторую итерацию
#
# </div>

# %% [markdown]
# # Поиск по изображениям для фотохостинга «Со Смыслом»

# %% [markdown]
# __Описание проекта:__  Фотохостинг для профессиональных фотографов «Со Смыслом» (“With Sense”) обладает отличительной особенностью — описание может предоставить не только тот, кто размещает фотографию, но и другие пользователи портала. Суть поиска заключается в следующем: пользователь сервиса вводит описание нужной сцены, а мервис выводит несколько фотографий с такой же или похожей сценой.

# %% [markdown]
# __Цель исследования:__ разработать демонстрационную версию поиска изображений по запросу пользователя.<br>Необходимо отфильтровать запрос в связи с ограничением: _поисковым сервисам и сервисам, предоставляющим возможность поиска, запрещено без разрешения родителей или законных представителей предоставлять любую информацию, в том числе, но не исключительно тексты, изображения, видео и аудио, содержащие описание, изображение или запись голоса детей_.

# %% [markdown]
# __Ход исследования:__
# <br><br>
# - Подготовка данных: загрузка датафреймов, получение общей информации;
# - Предобработка данных: обработка пропусков, поиск аномалий;
# - Исследовательский анализ: построение распределений и зависимостей в данных;
# - Векторизация изображений и запросов;
# - Обучение модели, предсказание на тестовых векторизированных данных.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 Да, это хорошая практика - дать описание контекста и проблемы, которую мы решаем. </div>

# %% [markdown]
# ## Подготовка

# %% [markdown]
# ### Загрузка библиотек и создание функций

# %% [markdown]
# Установка необходимых библиотек:

# %%
import math
import re

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import torch
import torch.nn.functional as F
import torch.nn as nn

from PIL import Image
from pathlib import Path
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModel
from tqdm import notebook

from sklearn.linear_model import LinearRegression, Ridge
from sklearn.preprocessing import StandardScaler, MinMaxScaler, Normalizer
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import accuracy_score, log_loss, f1_score, mean_squared_error, root_mean_squared_error

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Conv2D, MaxPooling2D, BatchNormalization, Reshape, RepeatVector, LSTM, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import image_dataset_from_directory

from keras.applications.resnet50 import preprocess_input

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Отлично, все нужные библиотеки импортированы в начале ноутбука.Это хорошая практика.</div>

# %% [markdown]
# Сохраним путь в переменную

# %%
PATH = '/kaggle/input/datasets/tomatour/to-upload/'

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Очень грамотное решение - выделить базовый путь к папке с данными в константу </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Старайся не делать такие длинные строки. Стандарт PEP8 регулирует длину строки 79 символов. Придерживаться такого очень сложно, но лучше хотя-бы вмещать в экран, чтобы не приходилось использовать scroll.
#
#
# А еще  если сомневаешься, как отформатировать правильно - всегда можно найти какой-нибудь оналйн-форматтер, например этот
#
#   https://extendsclass.com/python-formatter.html
#
#
# В качестве дополнительного развития могу порекомендоваь книгу "PYTHON  чистый код для продолжающих", Эл Свейгарт
#
#
#
#
# </div>

# %%
def short_summary(dataframe):
	print('\033[1mКраткая информация:\033[0m\n')
	dataframe.info()
	print('\n\n\033[1mРазмерность:\033[0m', dataframe.shape, end='\n\n\n')
	print('\033[1m5 случайных строк датафрейма:\033[0m\n')
	display(dataframe.sample(5))

# %%
def read_func(file_name, sep=',', names=None, path=PATH):
	if names == None:
		header=0
	else:
		header=1

	try:
		dataset = pd.read_csv(path + file_name, sep=sep, names=names, header=header)
	except:
		print('Файл не найден')
		return
	return dataset

# %% [markdown]
# ### Загрузка данных

# %% [markdown]
# Получим данные и выведем краткую информацию о них:

# %%
start_train_data = read_func('train_dataset.csv')

# %%
start_crowd_data = read_func('CrowdAnnotations.tsv', sep='\t', names=['image', 'query_id', 'ratio', 'agree', 'disagree'])

# %%
start_exp_data = read_func('ExpertAnnotations.tsv', sep='\t', names=['image', 'query_id', 'first', 'sec', 'third'])

# %%
start_test_queries = read_func('test_queries.csv', sep='|')

# %%
start_test_images = read_func('test_images.csv')

# %%
short_summary(start_train_data)
# Out:
# Краткая информация:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image       5822 non-null   object
#  1   query_id    5822 non-null   object
#  2   query_text  5822 non-null   object
# dtypes: object(3)
# memory usage: 136.6+ KB
#
#
# Размерность: (5822, 3)
#
#
# 5 случайных строк датафрейма:
#                           image                     query_id  \
# 2689  3025549604_38b86198f5.jpg  3572267708_9d8a81d4a4.jpg#2
# 5107  2984174290_a915748d77.jpg  2901880865_3fd7b66a45.jpg#2
# 4880  3213992947_3f3f967a9f.jpg  1096395242_fc69f0ae5a.jpg#2
# 3319  2682382530_f9f8fd1e89.jpg  3214885227_2be09e7cfb.jpg#2
# 1032   127490019_7c5c08cb11.jpg  2553550034_5901aa9d6c.jpg#2
#
#                                              query_text
# 2689  Three girls in colorful outfits are dancing un...
# ...

# %%
short_summary(start_crowd_data)
# Out:
# Краткая информация:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47828 entries, 0 to 47827
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   image     47828 non-null  object
#  1   query_id  47828 non-null  object
#  2   ratio     47828 non-null  float64
#  3   agree     47828 non-null  int64
#  4   disagree  47828 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.8+ MB
#
#
# Размерность: (47828, 5)
#
#
# 5 случайных строк датафрейма:
#                            image                     query_id     ratio  \
# 41340  3727752439_907795603b.jpg  3437654963_c4fdc17e8b.jpg#2  0.000000
# 1814   1348304997_afe60a61df.jpg  3518126579_e70e0cbb2b.jpg#2  0.000000
# 27445  3214573346_d3a57f0328.jpg  2892995070_39f3c9a56e.jpg#2  0.000000
# 32938  3406930103_4db7b4dde0.jpg  2953015871_cae796b6e7.jpg#2  0.000000
# 30675  3316725440_9ccd9b5417.jpg  3670907052_c827593564.jpg#2  0.333333
#
# ...

# %%
short_summary(start_exp_data)
# Out:
# Краткая информация:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5820 entries, 0 to 5819
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   image     5820 non-null   object
#  1   query_id  5820 non-null   object
#  2   first     5820 non-null   int64
#  3   sec       5820 non-null   int64
#  4   third     5820 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 227.5+ KB
#
#
# Размерность: (5820, 5)
#
#
# 5 случайных строк датафрейма:
#                           image                     query_id  first  sec  \
# 998   2225231022_1632d0a5aa.jpg  3286822339_5535af6b93.jpg#2      1    1
# 3874  3359551687_68f2f0212a.jpg  2682382530_f9f8fd1e89.jpg#2      1    2
# 4404  3521374954_37371b49a4.jpg  3627011534_485f667b10.jpg#2      1    2
# 2081   270816949_ffad112278.jpg  3364026240_645d533fda.jpg#2      1    2
# 3304  3197981073_3156963446.jpg  3197981073_3156963446.jpg#2      4    4
#
# ...

# %%
short_summary(start_test_queries)
# Out:
# Краткая информация:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  500 non-null    int64
#  1   query_id    500 non-null    object
#  2   query_text  500 non-null    object
#  3   image       500 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 15.8+ KB
#
#
# Размерность: (500, 4)
#
#
# 5 случайных строк датафрейма:
#      Unnamed: 0                     query_id  \
# 130         130  2517284816_9b8fd3c6b6.jpg#0
# 17           17  1319634306_816f21677f.jpg#2
# 156         156   269650644_059a84ece5.jpg#1
# 469         469   782401952_5bc5d3413a.jpg#4
# 237         237  3122579598_14841c038a.jpg#2
#
#                                             query_text  \
# 130                              A crowd of children .
# 17             A large tan dog sits on a grassy hill .
# ...

# %%
short_summary(start_test_images)
# Out:
# Краткая информация:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   image   100 non-null    object
# dtypes: object(1)
# memory usage: 932.0+ bytes
#
#
# Размерность: (100, 1)
#
#
# 5 случайных строк датафрейма:
#                         image
# 3   1429546659_44cb09cbe2.jpg
# 73  2737233999_34d60dc5c3.jpg
# 36  3487131146_9d3aca387a.jpg
# 58  3435015880_eda46ff50f.jpg
# 80  1991806812_065f747689.jpg

# %% [markdown]
# __Предварительные выводы о данных:__ обнаружен неинформативный признак "Unnamed: 0", который необходимо исключить, данные приведены в нужных типах

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Даные загружены, проведено первичное знакомство</div>

# %% [markdown]
# ### EDA

# %% [markdown]
# Примеры изображений:

# %%
fig = plt.figure(figsize=(12, 12))

for i in range(8):
	fig.add_subplot(4, 4, i+1)

	image = Image.open(Path(PATH, 'train_images', start_train_data['image'].sample(8).iloc[i]))

	plt.imshow(image)

	plt.xticks([])
	plt.yticks([])

for i in range(8):
	fig.add_subplot(4, 4, i+9)

	image = Image.open(Path(PATH, 'test_images', start_test_queries['image'].sample(8).iloc[i]))

	plt.imshow(image)

	plt.suptitle('Выборка изображений из тестового и тренировочного датасетов')
	plt.xticks([])
	plt.yticks([])

# %% [markdown]
# В данных не обнаружили дубликаты:

# %%
start_crowd_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
start_crowd_data.isna().sum()
# Out:
# image       0
# query_id    0
# ratio       0
# agree       0
# disagree    0
# dtype: int64

# %%
plt.figure(figsize=(12,4))

sns.countplot(data=start_crowd_data, y='ratio', stat='percent', order=start_crowd_data['ratio'].value_counts().index)

plt.title('Распределение долей правильной пары "описание-изображение" согласно данным краудсорсинга\n')
plt.show()

# %% [markdown]
# Распределение числа оценок по экспертам:

# %%
start_exp_data.hist(figsize=(12,6))

plt.show()

# %% [markdown]
# Создадим копию датасета для дальнейшей работы

# %%
exp_data = start_exp_data.copy()

# %% [markdown]
# Посчитаем среднюю оценку экспертов и нормализуем:

# %%
exp_data['exp_ratio'] = start_exp_data.loc[:,'first':'third'].apply('mean', axis=1)

# %%
exp_data['exp_ratio'].describe()
# Out:
# count    5820.000000
# mean        1.647824
# std         0.806288
# min         1.000000
# 25%         1.000000
# 50%         1.333333
# 75%         2.000000
# max         4.000000
# Name: exp_ratio, dtype: float64

# %%
exp_data['exp_ratio'] = (exp_data['exp_ratio'] - exp_data['exp_ratio'].min()) / (exp_data['exp_ratio'].max() - exp_data['exp_ratio'].min())

# %%
exp_data['exp_ratio'].describe()
# Out:
# count    5820.000000
# mean        0.215941
# std         0.268763
# min         0.000000
# 25%         0.000000
# 50%         0.111111
# 75%         0.333333
# max         1.000000
# Name: exp_ratio, dtype: float64

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/cf/RomanianTrafficSign_30-Stop_1971.svg/250px-RomanianTrafficSign_30-Stop_1971.svg.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# А вот с делением на 4 давай рабираться подробнее.
#
# Средняя оценка эксперта (как и любая оценка эксперта) лежитв диапазоне [1, 4].  Поэтому если ты просто разделишь на 4, то получишь [0.25, 1].  Но нас интересует диапазон [0, 1].  Получить его можно с помощью простого линейного преобразования `(x-1)/4`
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# 	<font size="3"><b>Комментарий студента</b></font>
#
# Почему-то подумал, что деление на макс. приведет к нужному диапазону.. А `(x-1)/4`  мне тоже не нравится - ведь тогда будет [0; 0,75]. Решил применить ручной MinMax)
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  <b>v2</b> 👍
#
# Молодец, что думаешь и сомневаешься.
#
# Скажу честно - я просто на по невнимательности написал тебе неверную формулу ))..  Корректно будет `(x-1)/3`
#
#
# </div>

# %%
exp_data.sample(5)
# Out:
#                           image                     query_id  first  sec  \
# 4573  3567061016_62768dcce1.jpg  3125309108_1011486589.jpg#2      1    1
# 4830  3647750811_395fbd397e.jpg  1119015538_e8e796281e.jpg#2      3    3
# 4639  3584534971_b44f82c4b9.jpg  3361990489_92244a58ef.jpg#2      1    1
# 3900  3364151356_eecd07a23e.jpg  2999730677_0cfa1c146e.jpg#2      2    2
# 71    1167669558_87a8a467d6.jpg  2594042571_2e4666507e.jpg#2      1    1
#
#       third  exp_ratio
# 4573      1   0.000000
# 4830      4   0.777778
# 4639      2   0.111111
# 3900      2   0.333333
# 71        1   0.000000

# %%
start_train_data.loc[start_train_data['image'] == exp_data['image'].iloc[4184]]['query_text']
# Out:
# 1658             A wrinkled dog wading in shallow water .
# 1686                             dogs playing in a stream
# 1935    A dog wading in the water with a ball in his m...
# 2522    a grey dog swimming through a river with a sti...
# 2578        A man is riding a dirt bike over some rocks .
# 2588    A man in red pushes his motocross bike up a ro...
# 2702    Man fly fishing in a small river with steam in...
# 4341           A man on a tag line going into the water .
# Name: query_text, dtype: object

# %%
image = Image.open(Path(PATH, 'train_images', exp_data['image'].iloc[4184]))

plt.imshow(image)

# %% [markdown]
# ### Объединение датафреймов

# %% [markdown]
# Соберем данные пользователей и экспертов

# %% [markdown]
# Список всех запросов:

# %%
query_list = start_train_data.drop_duplicates(subset='query_id')[['query_id', 'query_text']]

# %%
data_sum = exp_data.merge(start_crowd_data, on = ['image', 'query_id'], how='left')

# %%
data_sum = data_sum.merge(query_list, on=['query_id'], how='left')

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/cf/RomanianTrafficSign_30-Stop_1971.svg/250px-RomanianTrafficSign_30-Stop_1971.svg.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
#
# В этом проекте есть несколько возможных стратегий работы с обучающими и краудсорс оценками,  вот эти стратегии с плюсами и минусами:
#
#
#  - использовать соединение через outer, в этом случае, при корректной обработке пропусков мы можем получить более 50К размеченых пар. К плюсам данного подхода можно отнести большое количество данных. Минус - в основном это будут данные, размеченные краудсорсерами, а там качество раметки ниже.
#  - использовать только экспертные оценки. плюс - высокое качество данных (разметка имеет шкалу). Минус - данных меньше.  Поясню по поводу качества разметки на примере: если на изображении одна собака, а в описании "две собаки бегут по берегу", то эксперты поставять соответствие 0,6-0,7 (переводя в шкалу 0-1), а краудсорсеры поставят 0.  Но на экспертных оценках модель хотя-бы научится находить собак, а на краудсор оценках ничему не начится.
#
#  - использование соединения через left.  Данный подход очевидно проигрывает второму варианту: данных столько же, нужно дополнительно возиться с объединением, но качество разметки снижается.. Но это соответсвует предложениям авторов проекта, поэтому такой подход имеет право на жизнь
#
#  - объединение через inner. Тут все плохо - и данных ОЧЕНЬ мало (в два раза меньше, чем использовать только экспертные оценки) и качество у них "подпорчено". И навыков по обработке пропусков не получаем.....
#
# Сейчас ты соединил экспертные и краудсорс оценки, через `inner`, поэтомуто мы просто потеряли половину данных, не получив ничего в замен (точнее только ухудшив наши оценки).
#
# Пожалуйста используй любую другую стратегию, кроме внутреннего соединения. Слишком мало данных при этом получается.
#
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# 	<font size="3"><b>Комментарий студента</b></font>
#
# Не знал как подступиться... Терперь решил использовать только оценки экспертов, а где есть - еще и пользователей, как небольшая прибавка.
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# 	<b>v2</b> исправлено 👍 </div>

# %%
data_sum.image.nunique()
# Out:
# 1000

# %%
data_sum.sample(5)
# Out:
#                           image                     query_id  first  sec  \
# 1614  2510020918_b2ca0fb2aa.jpg  3222041930_f642f49d28.jpg#2      1    1
# 3897  3364151356_eecd07a23e.jpg  1764955991_5e53a28c87.jpg#2      2    2
# 1070   226607225_44d696db6b.jpg   533979933_a95b03323b.jpg#2      2    2
# 2966  3095225232_2e6e6dc92e.jpg  2594042571_2e4666507e.jpg#2      1    1
# 2574  2933912528_52b05f84a1.jpg  2926595608_69b22be8d4.jpg#2      1    1
#
#       third  exp_ratio  ratio  agree  disagree  \
# 1614      1   0.000000    NaN    NaN       NaN
# 3897      2   0.333333    0.0    0.0       3.0
# 1070      2   0.333333    NaN    NaN       NaN
# 2966      2   0.111111    NaN    NaN       NaN
# 2574      1   0.000000    NaN    NaN       NaN
#
#                                              query_text
# 1614  A man is standing up , reading a newspaper , a...
# 3897  A dog with a ball in his mouth running down a ...
# 1070  A boy is on the beach with a paddle in his han...
# ...

# %% [markdown]
# При получении итоговой оценки соответствия отдадим больший вес голосу экспертов. При этом запросы для которых нет оценок пользователей учитывать не будем

# %%
data_sum['final_ratio'] = data_sum['exp_ratio']

# %%
cond = data_sum['ratio'].notna()

# %%
data_sum.loc[cond, 'final_ratio'] = (
	data_sum.loc[cond, 'ratio'] * 0.2 +
	data_sum.loc[cond, 'exp_ratio'] * 0.8
)

# %%
data_sum.final_ratio.describe()#.sample(5)
# Out:
# count    5820.000000
# mean        0.199565
# std         0.256015
# min         0.000000
# 25%         0.000000
# 50%         0.111111
# 75%         0.266667
# max         1.000000
# Name: final_ratio, dtype: float64

# %% [markdown]
# Очистим запросы от нарушающих правила текстов:

# %%
pattern = r'\b(baby|babies|boy|boys|child|children|girl|kid|infant|newborn|teen|toddler|toddlers|young|youngster|(?:\bage(?:d)?\s?(?:[1-9]|1[0-6]))|(?:\b(?:[1-9]|1[0-6])\s?years? old))'

# %% [markdown]
#  <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# У тебя уже есть какой-то список со стоп-словами.  Как он связан с регуляркой, которую ты здесь пишешь?
#
# Если ты захочешь убрать или добавить новое слово, то куда их нужно добавить? Подумай об этом.
#
# В идеале список стоп-слов должен определяться только в одном месте, а не в нескольких.
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# 	<font size="3"><b>Комментарий студента</b></font>
#
# Специально написал в начале, чтобы потом благополучно забыть) Поправил тут и там
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# 	<b>v2</b> исправлено 👍 </div>

# %% [markdown]
# Список запрещенных изображений:

# %%
censored_img = []

for q in query_list.query_text:
	if re.search(pattern, q, re.IGNORECASE):
		censored_img.append(query_list.loc[query_list['query_text'] == q, 'query_id'].item()[0:-2])

# %% [markdown]
# Очищаем

# %%
data_sum_censored = data_sum[~data_sum['image'].isin(censored_img)]

# %%
data_sum_censored.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4156 entries, 0 to 5819
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   image        4156 non-null   object
#  1   query_id     4156 non-null   object
#  2   first        4156 non-null   int64
#  3   sec          4156 non-null   int64
#  4   third        4156 non-null   int64
#  5   exp_ratio    4156 non-null   float64
#  6   ratio        1764 non-null   float64
#  7   agree        1764 non-null   float64
#  8   disagree     1764 non-null   float64
#  9   query_text   4156 non-null   object
#  10  final_ratio  4156 non-null   float64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 389.6+ KB

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Ты удаляешь комментарии, в которых есть слова, обозначающие детей. Но наша задача убрать изображения, содержащие детей. Есть два способа сделать это:
#
#  - Определить список плохих изображений, как изображения удовлетворяющие условиям:
# 	- Комментарий содержит плохие слова
# 	- <b>Оценка соответствия комментария и изображения выше порога.</b>
#  - Удалить из нашего датасета все пары "изображение/описание" с плохими изображениями.
#
#
# И второй, очень красивый способ. Он основан на том, что `query_id` содержит в с себе имя изображения, для которого он был написан (такая пасхалочка от авторов датасета).
#
#  - Определить список плохих комментариев
#  - У `query_id`  плохих комментариев отрезать два последних символа и получим список плохих изображений.
#
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# 	<font size="3"><b>Комментарий студента</b></font>
#
# Воспользовался красивой подсказкой!
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# 	<b>v2</b> исправлено 👍 </div>

# %%
data_sum_censored = data_sum_censored.drop(['ratio', 'agree', 'disagree', 'first', 'sec', 'third', 'exp_ratio'], axis=1)

# %%
data_sum_censored
# Out:
#                           image                     query_id  \
# 0     1056338697_4f7d7ce270.jpg  3181701312_70a379ab6e.jpg#2
# 1     1056338697_4f7d7ce270.jpg  3207358897_bfa61fa3c6.jpg#2
# 2     1056338697_4f7d7ce270.jpg  3286822339_5535af6b93.jpg#2
# 3     1056338697_4f7d7ce270.jpg  3360930596_1e75164ce6.jpg#2
# 4     1056338697_4f7d7ce270.jpg  3545652636_0746537307.jpg#2
# ...                         ...                          ...
# 5815   997722733_0cb5439472.jpg  2981702521_2459f2c1c4.jpg#2
# 5816   997722733_0cb5439472.jpg  2985679744_75a7102aab.jpg#2
# 5817   997722733_0cb5439472.jpg  3150742439_b8a352e1e0.jpg#2
# 5818   997722733_0cb5439472.jpg  3375070563_3c290a7991.jpg#2
# 5819   997722733_0cb5439472.jpg   486917990_72bd4069af.jpg#2
#
#                                              query_text  final_ratio
# 0       A man sleeps under a blanket on a city street .     0.111111
# 1     A woman plays with long red ribbons in an empt...     0.222222
# ...

# %% [markdown]
# __Вывод:__ в данном разделе ознакомились с данными и оценили внутренние связи, провели очистку от фото, нарушающих правила сервиса, сформировали единую оценку схожести пары "запрос-изображение"

# %% [markdown]
# ## Подготовка данных и изображений

# %% [markdown]
# ### Векторизация изображений

# %% [markdown]
# Воспользуемся генератором для подготовки изображений:

# %%
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_gen_flow = train_datagen.flow_from_dataframe(
	dataframe=data_sum_censored,
	directory=Path(PATH, 'train_images'),
	x_col='image',
	y_col='final_ratio',
	target_size=(224, 224),
	batch_size=16,
	class_mode='input',
	seed=42,
	shuffle=False
)
# Out:
# Found 4156 validated image filenames.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/cf/RomanianTrafficSign_30-Stop_1971.svg/250px-RomanianTrafficSign_30-Stop_1971.svg.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# Вот здесь проблема, и она заключается в том, что  у flow_from_dataframe есть дефолтный аргумент shuffle=True, а значит выдаваемые им изображения перемешиваются, и идут совсем не в том порядке,как в датфрейме.  Как следствие мы получаем эмбеддинги не соответствующие изображениям в датафрейме.</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# 	<font size="3"><b>Комментарий студента</b></font>
#
# Это объясняет ужасающие результаты модели)) Догадывался что основная проблема в подготовке данных, но вот не видел этот параметр
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# 	<b>v2</b> исправлено 👍 </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Модель ResNEt обучалась на изображениях размером 224х224. Подавая изображения других размеров ты во первых используешь модель не в оптимальном режиме. Во вторых сжимая изображения ты теряешь информацию.
#
# ----------------------------
#
# Более того, чтобы эмбеддинги  были качественными, стоит использовать специальную предобработку, повторяющую условия, при которых модель обучалась.
#
# В разделе "компьютерное зрение с pytorch" приведен образец кода, как проводить эту предобработку при использовани моделей pytorch.
#
# В случае Keras нужно использовать специальную фукнцию preprocess_input
#
# 	from keras.applications.resnet50 import preprocess_input
# 	...
# 	train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
#
#
# --------------
#
# Важно: препроцессинг в данном случае отменяет необходимость делай рескейл. Т.е. `preprocessing_function` мы указываем вместо `rescale`.
#
#
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# А еще стоит обратить внимание, что изображения у нас не квадратные, а значит они будут сжаты до квадратов с изменением пропорций.
#
# В прекоде, который был дан в теории для pytorch модели эта проблема быларешена тем, что мы вырезали квадрат из середины и работали уже с ним.
#
# Думаю что что-то подобное стоит попробовать и при использовании keras.
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#
# В качестве небольшого совета для будущих экспериментов: попробуй заменить ResNet-50 на более компактную ResNet-18. Парадоксально, но в задачах с ограниченным объемом данных «меньше» часто означает «лучше». Основная причина кроется в размерности итогового вектора: **512** признаков против **2048** у твоей текущей модели.
#
#
#
# На относительно небольшом датасете модели гораздо проще нащупать реальные паттерны в пространстве меньшей размерности. Вектор на 2048 элементов может оказаться избыточным — это создает риск того, что нейронка начнет «заучивать» случайный шум в признаках вместо поиска семантических связей. Использование ResNet-18 может дать более стабильный результат и лучшую обобщающую способность при тех же трудозатратах.
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# 	<font size="3"><b>Комментарий студента</b></font>
#
# Планирую потом поэкспериментировать с проектом и расширить как-нибудь, спасибо за советы!
#
# </div>

# %% [markdown]
# Напишим функции.<br>
# Воспользуемся моделью ResNet50 для векторизации набора изображений

# %%
def create_model():
	backbone = ResNet50(input_shape=(224, 224, 3),
						include_top=False,
						weights='imagenet')

	model = Sequential()
	model.add(backbone)
	model.add(GlobalAveragePooling2D())
	model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.001), metrics=['mae'])

	return model

# %%
def image_vectorization(model, df):
	predictions = model.predict(df)
	return predictions

# %%
image_embeddings = image_vectorization(create_model(), train_gen_flow)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785619918.429177      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1785619918.435228      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
#   3/260 ━━━━━━━━━━━━━━━━━━━━ 18s 72ms/step
# I0000 00:00:1785619934.077369     137 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 34s 103ms/step

# %%
image_embeddings.shape
# Out:
# (4156, 2048)

# %% [markdown]
# ### Векторизация текстов описаний

# %% [markdown]
# Для векторизации запросов используем BERT:

# %% [markdown]
#  <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Я бы не стал использовать здесь `keras_nlp`.  Библиотека достаточно старая, сейчас индустриальным стандартом является transformers.
#
#
# Библиотеку `keras_nlp` впервые использовали студенты первых потоков, тогда это было еще адекватно, для совместимости с фреймворком keras, но последние годы pytorch стал безусловным лидером.
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Подсвечу желтым, чтобы не потерялось.
#
# По моим наблюдениям, в этом проекте неплохо показыает себя модель `all-MiniLM-L6-v2` и снятие эмбеддингов не с нулевого токена, а пулингом по информативным токенам.
#
# Запустить её можно либо через transformers, либо через sentence-transformers
#
# https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# 	<font size="3"><b>Комментарий студента</b></font>
#
# Решил использовать модель
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# 	<b>v2</b> исправлено 👍 </div>

# %%
def mean_pooling(model_output, attention_mask):
	token_embeddings = model_output[0]
	input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
	return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

# %%
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
model = AutoModel.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
# Out:
# ...
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
def text_emd(corpus):

	encoded = tokenizer(corpus, padding=True, truncation=True, return_tensors='pt')

	with torch.no_grad():
		output = model(**encoded)

	text_embeddings = mean_pooling(output, encoded['attention_mask'])

	text_embeddings = F.normalize(text_embeddings, p=2, dim=1)

	return text_embeddings

# %%
sentence_embeddings = text_emd(list(data_sum_censored.query_text))

# %%
sentence_embeddings.shape
# Out:
# torch.Size([4156, 384])

# %% [markdown]
# ### Объединение векторов

# %% [markdown]
# Объединяем эмбеддинги, получаем входные и целевой признаки:

# %%
image_embeddings_norm = Normalizer().transform(image_embeddings)

# %%
sentence_embeddings_norm = Normalizer().transform(sentence_embeddings)

# %%
features = np.concatenate((image_embeddings_norm, sentence_embeddings_norm), axis=1)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  Вектора, полученные из текста и изображения объеденены👍 </div>

# %%
features.shape
# Out:
# (4156, 2432)

# %%
target = np.array(data_sum_censored['final_ratio'])

# %%
target.shape
# Out:
# (4156,)

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# В качестве целевой метрики будем использовать RMSE благодаря интерпретируемости и штрафов за большую величину ошибок

# %% [markdown]
# ### Разбиение данных

# %% [markdown]
# Разобьем данные на тренировочную и валидационную

# %%
groups = data_sum_censored['image']

# %%
gss = GroupShuffleSplit(n_splits=1, train_size=.75, random_state=42)
train_indices, val_indices = next(gss.split(X=features, y=target, groups=groups))

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Отлично, благодаря использованию GroupShuffleSplit ты исключаешь попадание одного изображения в обучающий и валидационный наборы.</div>

# %%
features_train, features_val = features[train_indices], features[val_indices]
target_train, target_val = target[train_indices], target[val_indices]

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Только давай разберемся с выборками. Финальное тестирование (визуальное) мы делаем на отложенной выборке. Поэтому выборка,которую ты сейчас отделил играет роль валидационной. Есть смысл в её названии использовать слово valid а не test</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# 	<font size="3"><b>Комментарий студента</b></font>
#
# Не совсем понял - вроде бы везде val стоит
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# 	<b>v2</b> Сорри. видимо это у меня глаз замылися </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
#
#
# Также корректно применен `MinMaxScaler` ~`StandardScaler`~: обучен  на  на трейне и применен к валидации. Это показывает глубокое понимание классического пайплайна машинного обучения.
#
# Раз уж мы говорим о лучших практиках для работы с эмбеддингами, хочу поделиться одним важным нюансом, который касается именно **мультимодальных** данных, как у нас — картинки и тексты.
#
# Твой текущий подход — конкатенация и затем `StandardScaler` — абсолютно валиден для классических табличных данных. Но для эмбеддингов он может быть неоптимален. `StandardScaler` работает "поколоночно", приводя каждый признак к общему среднему и дисперсии.
#
#
# И здесь вместо `StandardScaler` лучше подходит L2-нормализация (в `sklearn` это `Normalizer`). Этот метод масштабирует каждый вектор (каждую строку целиком) к единичной длине. Он убирает влияние "магнитуды" вектора (которая часто является шумом) и оставляет только его **направление** в многомерном пространстве — а именно оно и несет основную семантическую информацию.
#
# Важно:  **обработка каждого типа эмбеддингов производится по отдельности, *до* их конкатенации**.
#
# Таким образом, более продвинутый пайплайн мог бы выглядеть так:
# 1.  Получаем матрицу эмбеддингов для изображений `X_img`.
# 2.  Получаем матрицу эмбеддингов для текстов `X_text`.
# 3.  Применяем `Normalizer()` к `X_img` и `X_text` **по отдельности**.
# 4.  Конкатенируем уже нормализованные матрицы.
#
# Такой подход гарантирует, что и визуальные, и текстовые признаки вносят в модель сопоставимый вклад, не искажая при этом структуру каждого из исходных пространств. Это знание будет очень полезно тебе в будущих проектах.
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# 	<font size="3"><b>Комментарий студента</b></font>
#
# Решил поэкспериментировать с sklearn, теперь обрабатываем отдельно
#
# </div>

# %% [markdown]
# ### Baseline-модель

# %% [markdown]
# Построим базовую модель регрессии:

# %%
model_lr = LinearRegression().fit(features_train, target_train)

# %%
root_mean_squared_error(target_train, model_lr.predict(features_train))
# Out:
# 0.19057802561786052

# %%
preds_val = model_lr.predict(features_val)

# %%
root_mean_squared_error(target_val, preds_val)
# Out:
# 0.3054211424258646

# %% [markdown]
# Метрики на валидации сильно упали в сравнении с трейном - можно предположить переобучение. Однако для адекватной оценки необходимо рассмотреть другую модель.

# %% [markdown]
# ### НС-модель

# %% [markdown]
# Построим полносвязную модель нейронной сети

# %%
torch.manual_seed(42)
np.random.seed(42)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
X_train = torch.FloatTensor(features_train).to(device)
y_train = torch.FloatTensor(target_train).to(device)
X_val = torch.FloatTensor(features_val).to(device)
y_val = torch.FloatTensor(target_val).to(device)

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# В этом раздеел есть проблема и заключается она в следующем. Для векторизации изображений и пописаний ты  использовал  Keras.  А вот итоговую нейронку решил сделать с помощью torch.
#
# Поддержка двух DL фреймворков - это будет ад для девопса. Поэтому хорошей практикой является использование одного фреймворка в одном проекте.
#
# Я бы рекомендовал для картинок взять Resnet18 (готовый код есть в теории спринта),  для текстов взять sentence-transformers (используют pytorch), а эту  нейронку уже оставить как есть
# </div>

# %% [markdown]
# Будем обучать модель с подбором гиперпараметров.

# %% [markdown]
# Функция-инициализации архитектуры сети:

# %%
def init_model(
	device,
	lr,
	first_drop=0
):
	torch.manual_seed(42)
	np.random.seed(42)

	n_in_neurons = 2432
	n_hidden_neurons_1 = 512
	n_hidden_neurons_2 = 256
	n_hidden_neurons_3 = 512
	n_hidden_neurons_4 = 256
	n_hidden_neurons_5 = 128
	n_out_neurons = 1

	neur_net = nn.Sequential(
		nn.Linear(n_in_neurons, n_hidden_neurons_1),
		nn.BatchNorm1d(n_hidden_neurons_1),
		nn.ReLU(),
		nn.Dropout(p=first_drop),
		nn.Linear(n_hidden_neurons_1, n_hidden_neurons_2),
		nn.BatchNorm1d(n_hidden_neurons_2),
		nn.ReLU(),
		nn.Linear(n_hidden_neurons_2, n_hidden_neurons_3),
		nn.BatchNorm1d(n_hidden_neurons_3),
		nn.ReLU(),
		nn.Linear(n_hidden_neurons_3, n_hidden_neurons_4),
		nn.BatchNorm1d(n_hidden_neurons_4),
		nn.ReLU(),
		nn.Linear(n_hidden_neurons_4, n_hidden_neurons_5),
		nn.BatchNorm1d(n_hidden_neurons_5),
		nn.ReLU(),
		nn.Linear(n_hidden_neurons_5, n_out_neurons)
	)

	optimizer = torch.optim.AdamW(neur_net.parameters(), lr=lr)

	loss = nn.MSELoss()

	neur_net = neur_net.to(device)

	return neur_net, optimizer, loss

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# **Архитектура и Loss-функция:**
# Ты используешь функцию активации `Sigmoid` на последнем слое в паре с `L1_loss`/`MSELoss`. Хотя технически это допустимо (значения остаются в диапазоне [0, 1]), с точки зрения оптимизации нейросетей это неэффективный выбор.
#
# **В чем проблема:**
#
# 1. **Затухание градиентов (Vanishing Gradients):** Когда выход модели близок к 0 или 1 (на "хвостах" сигмоиды), её производная стремится к нулю. В сочетании с квадратичной ошибкой это приводит к тому, что градиент становится ничтожно малым. Сеть практически перестает обучаться, даже если предсказание сильно отличается от таргета.
# 2. **Невыпуклость (Non-convexity):** Комбинация нелинейной сигмоиды и MSE создает сложную невыпуклую поверхность функции потерь с множеством локальных минимумов и "плато", в которых оптимизатор может застрять.
#
# **Рекомендация:**
#
# * **Вариант 1 (Предпочтительный):** Замени функцию потерь на `BCELoss`. Она математически "компенсирует" экспоненту в сигмоиде, обеспечивая сильные и стабильные градиенты. Это стандарт для таргетов в диапазоне [0, 1].
# * **Вариант 2:** Если хочешь оставить `MSE`, убери `Sigmoid` с последнего слоя (используй линейный выход). Правда, тогда предсказания могут выходить за пределы диапазона [0, 1].
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# 	<font size="3"><b>Комментарий студента</b></font>
#
# Убрал сигмоиду, добавлял, так как хотел к [0,1] привести результат
#
# </div>

# %% [markdown]
# Функция обучения. Проводить обучение будем без ограничения по числу эпох до момента, когда зафиксируется падение метрики на протяжении 10 вчислений

# %%
def model_learn(X_train,
				X_val,
				y_val,
				y_train,
				device,
				lr=1e-2,
				first_drop=0.2,
				eval_count=10,
				batch_size=40,
				accumulation_iteration=8
			   ):

	rmse_best = float('inf')
	epochs = 0
	j = 0

	torch.manual_seed(42)
	np.random.seed(42)

	neur_net, optimizer, loss = init_model(
		device,
		lr=lr,
		first_drop=first_drop
	)

	top_model = neur_net
	num_batches = math.ceil(len(X_train)/batch_size)

	#Обучение выполняем до early stop
	while epochs <= 400:

		#Считаем эпохи
		epochs += 1

		order = np.random.permutation(len(X_train))

		neur_net.train()

		optimizer.zero_grad()

		for batch_i in range(num_batches):
			start_index = batch_i * batch_size

			batch_indexes = order[start_index:start_index+batch_size]
			X_batch = X_train[batch_indexes].to(device)
			y_batch = y_train[batch_indexes].to(device)

			preds = neur_net.forward(X_batch).flatten()

			loss_value = loss(preds, y_batch) / accumulation_iteration
			loss_value.backward()

			if (batch_i + 1) % accumulation_iteration == 0 or batch_i == num_batches - 1:
				optimizer.step()

				optimizer.zero_grad()

		if (epochs + 1) % eval_count == 0:
			neur_net.eval()

			val_preds = neur_net.forward(X_val.to(device)).flatten()
			rmse = root_mean_squared_error(val_preds.detach().cpu().numpy(), y_val.detach().cpu().numpy())

			#Запоминаем лучшие метрики и модель
			if rmse <= rmse_best:
					rmse_best = rmse
					top_model = neur_net
					j = 0
			else:
				j += 1
		#Таймер для остановки обучения
		if j == 20:
			break

	return rmse_best, top_model, loss_value.item(), val_preds, epochs

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Очень круто, что ты самостоятельно реализовал раннюю остановку</div>

# %%
first_drop = [0, 0.025, 0.05]
learning_rate = [6e-3, 3e-3, 1e-3, 6e-4, 3e-4, 1e-4]

# %% [markdown]
# Функци подбора параметров:

# %%
# %%time

all_data = []
iter_data = []
j = 0
b_rmse = float('inf')

for i in range(len(first_drop)):
	for k in range(len(learning_rate)):

		rmse, net, loss_train, top_y_preds, epochs = model_learn(
							X_train,
							X_val,
							y_val,
							y_train,
							device=device,
							lr=learning_rate[k],
							first_drop=first_drop[i],
							batch_size=16
										 )

		#Запоминаем лучшую модель
		if rmse <= b_rmse:
			b_rmse = rmse
			top_model = net

		iter_data = [epochs, first_drop[i], learning_rate[k], rmse, loss_train]
		all_data.append(iter_data)
# Out:
# CPU times: user 54min 31s, sys: 1min 3s, total: 55min 34s
# Wall time: 55min 45s

# %%
torch.save(top_model.state_dict(), "/kaggle/working/model.pth")

# %% [markdown]
# Информация о 10 лучших обученных моделях:

# %%
stat = (pd
	.DataFrame(data=all_data, columns=['Epochs', 'First_dropout_ratio', 'Learning_rate', 'RMSE_on_val', 'Loss_f'])
	.sort_values(by='RMSE_on_val')
	   )

stat.head(10)
# Out:
#     Epochs  First_dropout_ratio  Learning_rate  RMSE_on_val    Loss_f
# 9      329                0.025         0.0006     0.207784  0.005689
# 4      401                0.000         0.0003     0.208982  0.006855
# 1      401                0.000         0.0030     0.209442  0.002954
# 0      289                0.000         0.0060     0.209492  0.001169
# 14     329                0.050         0.0010     0.210095  0.005061
# 15     401                0.050         0.0006     0.210219  0.002838
# 12     289                0.050         0.0060     0.210400  0.002334
# 10     279                0.025         0.0003     0.210522  0.002748
# 3      401                0.000         0.0006     0.210978  0.001201
# 16     401                0.050         0.0003     0.210987  0.002784

# %% [markdown]
# ### Предсказание на тестовых данных

# %% [markdown]
# Теперь аналогично векторизуем и сгруппируем тестовые данные:

# %%
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
test_gen_flow = test_datagen.flow_from_dataframe(
	dataframe = start_test_images,
	directory = Path(PATH, 'test_images'),
	x_col ='image',
	y_col ='final_ratio',
	target_size = (224, 224),
	batch_size = 16,
	class_mode = 'input',
	seed = 42,
	shuffle=False
)
# Out:
# Found 100 validated image filenames.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/cf/RomanianTrafficSign_30-Stop_1971.svg/250px-RomanianTrafficSign_30-Stop_1971.svg.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# Здесь тоже проблемы с перемешиванием
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# 	<font size="3"><b>Комментарий студента</b></font>
#
# Не перемешиваем больше
#
# </div>

# %%
test_image_embeddings = image_vectorization(create_model(), test_gen_flow)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 9s 884ms/step

# %%
test_image_embeddings.shape
# Out:
# (100, 2048)

# %%
test_queries = start_test_queries.drop(['Unnamed: 0'], axis=1)

# %% [markdown]
# test_embeddings = text_emd(list(test_queries.query_text))

# %% [markdown]
# test_embeddings.shape

# %%
test_image_embeddings_norm = Normalizer().transform(test_image_embeddings)

# %% [markdown]
# test_embeddings_norm = Normalizer().transform(sentence_embeddings)

# %% [markdown]
# Входные данные получены. Используем их для предсказаний

# %%
def nn_prediction(model, embds):

	'''Выполняем предсказание с использованием модели на основании эмбедингов'''

	X = torch.FloatTensor(embds).to(device)

	model.eval()
	with torch.no_grad():
		predictions = model.forward(X).cpu().numpy().flatten()
		
	print('prediction', predictions.shape)

	
	return predictions

# %%
def query_transform(query, image_embeddings):

	'''Получаем строку запроса, получаем соответствующий вектор, объединяем с эмбедингами изображений, нормализуем'''

	text_embed = text_emd([query])

	'''print(text_embed.shape)
	print(text_embed)'''

	embeddings_norm = Normalizer().transform(text_embed)

	'''print(embeddings_norm)
	print(embeddings_norm.shape)
	print()
	print(image_embeddings)
	print(image_embeddings.shape)'''

	feature = np.concatenate((image_embeddings, np.tile(embeddings_norm, (image_embeddings.shape[0],1))), axis=1)

	print('features', features.shape)

	return feature

# %%
def pred_visualisation(preds, image_names):

	print(preds.shape)
	print(len(image_names))
	#Номера фото и соотв вероятности
	pred_df = pd.DataFrame({
		'image': image_names,
		'prob': preds
	})

	pred_df = pred_df.sort_values(by='prob', ascending=False).reset_index(drop=True)

	# Находим лучший результат и выводим
	best_image = pred_df.iloc[0]['image']
	best_score = pred_df.iloc[0]['prob']

	image = Image.open(PATH+f'test_images/{best_image}')

	return best_image, pred_df, image

# %%
def nn_query_prediction(
	query,
	image_embeddings,
	model,
	image_names=list(start_test_images['image'])
):

	print(f'Запрос:\n{query}\n')

	if re.search(pattern, query, re.IGNORECASE):
		print('THIS QUERY VIOLATES LOCAL LAWS\n')
		return

	embds = query_transform(query, image_embeddings)

	preds = nn_prediction(model, embds)

	best_image, pred_df, image = pred_visualisation(preds, image_names)

	pred_df = pred_df.head(10)

	print(pred_df)

	plt.imshow(image)
	plt.show()

	return best_image

# %% [markdown]
# Сгенерируем 10 случайных запросов и получем предсказания:

# %%
check_queries = test_queries.sample(10)['query_text']

# %%
for q in check_queries:

	nn_query_prediction(
	query=q,
	image_embeddings=test_image_embeddings_norm,
	model=top_model
)
# Out:
# Запрос:
# a kickboxer jumping for a kick
#
# features (4156, 2432)
# prediction (100,)
# (100,)
# 100
#                        image      prob
# 0  3421547427_53411b6278.jpg  0.505192
# 1  3722572342_6904d11d52.jpg  0.346911
# 2  3356748019_2251399314.jpg  0.342533
# 3  2517284816_9b8fd3c6b6.jpg  0.337746
# 4   989754491_7e53fb4586.jpg  0.325396
# 5  3393035454_2d2370ffd4.jpg  0.314903
# 6  2399219552_bbba0a9a59.jpg  0.302867
# 7  3089107423_81a24eaf18.jpg  0.299146
# 8  3142055158_01b9e4caa4.jpg  0.291310
# 9  3119913014_688d4997d7.jpg  0.274289
# Запрос:
# a small shaggy dog plays with a red ball on the grass .
#
# features (4156, 2432)
# prediction (100,)
# (100,)
# 100
#                        image      prob
# 0   661749711_6f408dad62.jpg  0.593839
# 1  3154152744_4e93ec8a62.jpg  0.511461
# 2   381514859_b40418d9c3.jpg  0.498841
# 3  1745110280_0cbff5e273.jpg  0.487300
# 4  2986716822_e220754d32.jpg  0.478930
# 5  3466891862_9afde75568.jpg  0.469092
# ...

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/cf/RomanianTrafficSign_30-Stop_1971.svg/250px-RomanianTrafficSign_30-Stop_1971.svg.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# <b>v2</b>
#
# Несмотря на использование самого качественного подхода  (sbert + раздельная l2 нормализация) поиск не работает, а модель стабильно выдает одну и ту же картику (почти всегда).
#
# Еще один тревожный сиптом - вероятности выходят за разумные пределы 0-1.
#
# По моему опыту это происходит из-за рассинхронизации пайплайнов подготовки данных для обучения и на этапе тестирования.
#
# Я проверил основные моменты, где может быть ошибка и нашел один - тестовые изображения не нормализуются.
#
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# 	<font size="3"><b>Комментарий студента</b></font>
#
# У меня уже кончились все лимиты на GPU и не так много времени осталось, поэтому не в силах решить проблему решил отправить такой вариант, извиняюсь) Действительно пропустил - поставил нормализацию самого запроса и в мозгу сразу щелкнула галочка, что все готово. Поправил и теперь модель значительно лучше работает
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  <b>v3</b> исправлено 👍
#
# ---
#
# Думаю тут извиняться особо не за что )). Но я рад что после внесенных изменений мы увидели более -менее адеватные результаты поиска.
#
# </div>

# %% [markdown]
# Для сравнения работы проведем эксперимент с опен-сорс моделью CLIP. Она предварительно обучена и не требует обучения

# %%
from sentence_transformers import SentenceTransformer

# %%
clip_model = SentenceTransformer("sentence-transformers/clip-ViT-B-32")
# Out:
# modules.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# 0_CLIPModel/model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# CLIPModel LOAD REPORT from: sentence-transformers/clip-ViT-B-32
# Key                                  | Status     |  |
# -------------------------------------+------------+--+-
# vision_model.embeddings.position_ids | UNEXPECTED |  |
# text_model.embeddings.position_ids   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# ...

# %% [markdown]
# Получим эмбеддинги изображений:

# %%
PATH_IMG = PATH + 'test_images/'

# %%
images = [Image.open(PATH_IMG + img) for img in start_test_images.image]

clip_image_embes = clip_model.encode(
	images,
	batch_size=64,
	normalize_embeddings=True
)

# %%
clip_image_embes.shape
# Out:
# (100, 512)

# %% [markdown]
# Функция для определения схожести по запросу:

# %%
def clip_preds(query):

	print(f'Запрос:\n{query}\n')

	if re.search(pattern, query):
		print('THIS QUERY VIOLATES LOCAL LAWS\n')
		return
		
	clip_text_emb = clip_model.encode(
		query,
		normalize_embeddings=True,
		convert_to_numpy=True
		)

	similarity_scores = clip_model.similarity(clip_image_embes, clip_text_emb)

	best_value, best_idx = torch.max(similarity_scores, dim=0)
	
	print(start_test_images.image.iloc[best_idx].item())
	print(f'Сходство: {best_value.item()}')

	plt.imshow(Image.open(PATH_IMG + start_test_images.image.iloc[best_idx].item()))

	plt.show()
	
	return

# %%
for q in check_queries:

	clip_preds(q)
# Out:
# Запрос:
# a kickboxer jumping for a kick
#
# 1991806812_065f747689.jpg
# Сходство: 0.32227250933647156
# Запрос:
# a small shaggy dog plays with a red ball on the grass .
#
# 661749711_6f408dad62.jpg
# Сходство: 0.36100801825523376
# Запрос:
# Three dirt bike racers head over a jump .
#
# 3356748019_2251399314.jpg
# Сходство: 0.35266536474227905
# Запрос:
# Two dogs playing together in the snow .
#
# 3154152744_4e93ec8a62.jpg
# Сходство: 0.31205856800079346
# Запрос:
# A young girl in blue hat and coat is riding a tricycle .
#
# THIS QUERY VIOLATES LOCAL LAWS
#
# Запрос:
# A boy jumps off a tan rock .
#
# THIS QUERY VIOLATES LOCAL LAWS
#
# Запрос:
# A dog is pulling a red sled across the snow .
#
# 3247693965_845b3b4349.jpg
# Сходство: 0.31464579701423645
# Запрос:
# A black dog holding a weight in its mouth stands next to a person .
#
# 989851184_9ef368e520.jpg
# Сходство: 0.3376159369945526
# Запрос:
# A young boy throwing a rock into a pond in front of a large building .
#
# ...

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Функции написаны и со своей задачей справляются. Принимают на вход текст и находят изображение. Отрабатывают контроль "запрещенного контента".
#
# Да, ты прав, к сожалению работают они не очень. Причин несколько
#
#  - при подготовке признаков допущена ошибка - вектора изображений перепутаны и фактически модель училась на "мусоре".
#
# ----------------
#
# Как правило хороший результат в этом проекте удается достичь при выполнении следующих условий
#
#  - использование экспертных оценок
#  - векторизация изображений через pytorch, как есть в теории к спринту  (но с отрезанием только одного слоя)
#  - эмбеддинги через bert (лучший результат дает модель  `all-MiniLM-L6-v2`)
#  - раздельная l2 нормализация эмбеддингов
#  - упорное обучение нейронки (иногда тысячи эпох, в любом случае пока лосс снижается) с тщательным подбором гиперпараметров.
#
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Идеи и альтернативные подходы</b>
#   Если хочешь получить хорошо работающее решение без обучения, то можешь провести эксперимент с нейронной сетью CLIP от OPEN AI (это не обязательно, только если хочешь добиться хороших результатов в этом проекте).
#
#   Про эту нейронку много где написано, но можешь посмотреть например вот здесь  https://habr.com/ru/post/539312/.
#
#   А для написания  реализации наиболее удобной лично для меня оказалась библиотека sbert. https://www.sbert.net/examples/applications/image-search/README.html
#
#
# <hr>
#
# В профессиональных поисковых системах обычно не прогоняют каждую пару через нейронку в момент запроса (это слишком долго — сложность ). Вместо этого:
#
# 1. Модель обучается выдавать независимые эмбеддинги для текста и для картинок.
# 2. Эмбеддинги картинок сохраняются в специальную базу данных.
# 3. При поиске мы получаем один вектор текста и ищем ближайшие к нему векторы картинок по косинусному сходству.
#
# Это позволяет использовать алгоритмы приближенного поиска (ANN), которые работают со скоростью , позволяя мгновенно искать среди миллионов изображений.
#
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# 	<font size="3"><b>Комментарий студента</b></font>
#
# Провел эксперимент!
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# 	<b>v2</b> 👍 </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий v2</b>
#
# Проект принят. Поздравляю и желаю дальнейших успехов!
# </div>

# %% [markdown]
# __Выводы:__ мы получили векторы из тестовых данных и получили рекомендуемое изображение согласно обученной модели. Анализ результатов показывает невысокое качество предсказаний - __всего из запроса можно укзать, что угадано верно угадано 2 изображения__, что говорит о необходимости дополнительной работы над ней.<br>Так же мы рассмотрели работу модели CLIP от OpenAI, результаты которой оказались гораздо выше нашей модели

# %% [markdown]
# ## Выводы

# %% [markdown]
# В ходе настоящего проекта была проведена загрузка и знакомство с данными, проведен исследовательский анализ данных, анализ распредлений, оценка качества данных. Для подготовки данных к моделированию был проведен анализ оценок экспертов. Затем оценки экспертов и пользователей краудсорсинга были объединены и приведены к единой величине через соотношение 0,8:0,2. Для избежания нарушения нормативных правил были удалены записи с содержащие запрещенный контент.

# %% [markdown]
# Далее была выполнены векторизация изображений с использованием предобученной ResNet50 "без головы" и векторизация текстов с помощью модели BERT. Полученные массивы были объединены с помощью конкатенации в один.

# %% [markdown]
# В качестве целевой метрики была принята RMSE. Имеющийся входной массив были разбит на тренировочную и валидационную выборки. Далее они преобразованы в тензоры. Был выполнен подбор гиперпараметров нейросети для достижения высокой метрики.

# %% [markdown]
# С использованием сети с лучшим набором параметров было выполнено тестирование: поступал запрос, модель определяла изображение с наивысшим совпадением с описанием. Визуальный анализ соответствия пары "изображение-описание" показал крайне низкое качество работы модели на тестовых данных.

# %% [markdown]
# Для сравнительной оценки эксперимент был повторен с загруженной моделью CLIP-ViT, который показал высокое качество предсказаний.

# %% [markdown]
# Таким образом, данная модель вряд ли может в настоящей момент использоваться для выполнения задач заказчика. Для исправления ситуации можно использовать 2 принципиальных варианта:<br>
# - корректировка архитектуры имеющейся сети с целью улучшения её обучения, что требует времени на разработку;
# - использование имеющихся мощных моделей на другой архитектуре, однако это может потребовать больших вычислительных мощностей;
# - так же возможным вариантом является выполнение аугментаций - дублировать запросы с добавлением аугментированного изображения, чтобы модель лучше выделяла отличительные признаки.
